# %%
import os
from Crypto.Cipher import AES, DES, DES3, ARC4, ARC2
from Crypto.Util.Padding import pad
from Crypto.Random import get_random_bytes
# Out:
# b'\xc7\x8a\xc9\x19\xb6\xb7\xe6\x00b\xbb@iR\x96\xc2\xa0'
